# %% [markdown]
# # 2022 FIFA World Cup Predictions

# %% [markdown]
# Kaggle link: https://www.kaggle.com/datasets/martj42/international-football-results-from-1872-to-2017?resource=download

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#previewing the data
df = pd.read_csv('results.csv')
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
#home team data
results_home = pd.read_csv('results.csv')
results_home['date'] = pd.to_datetime(results_home['date'])
results_home = results_home.rename(columns = {'home_team':'team', 
                                              'away_team':'opponent',
                                              'home_score':'team_score',
                                              'away_score':'opponent_score'})
results_home['h_or_a'] = 'Home'

#away team data
results_away = pd.read_csv('results.csv')
results_away['date'] = pd.to_datetime(results_away['date'])
results_away = results_away.rename(columns = {'home_team':'opponent', 
                                              'away_team':'team',
                                              'home_score':'opponent_score',
                                              'away_score':'team_score'})
results_away = results_away[['date', 'team', 'opponent', 'team_score', 'opponent_score', 
                             'tournament', 'city', 'country', 'neutral']]
results_away['h_or_a'] = 'Away'

#concatenating home and away team data
results = pd.concat([results_home, results_away], axis = 0)
results
# Out:
#             date       team     opponent  team_score  opponent_score  \
# 0     1872-11-30   Scotland      England           0               0
# 1     1873-03-08    England     Scotland           4               2
# 2     1874-03-07   Scotland      England           2               1
# 3     1875-03-06    England     Scotland           2               2
# 4     1876-03-04   Scotland      England           3               0
# ...          ...        ...          ...         ...             ...
# 44342 2022-12-09  Argentina  Netherlands           2               2
# 44343 2022-12-10   Portugal      Morocco           0               1
# 44344 2022-12-10     France      England           2               1
# 44345 2022-12-13    Croatia    Argentina           0               3
# 44346 2022-12-14    Morocco       France           0               2
#
#            tournament     city   country  neutral h_or_a
# 0            Friendly  Glasgow  Scotland    False   Home
# 1            Friendly   London   England    False   Home
# 2            Friendly  Glasgow  Scotland    False   Home
# 3            Friendly   London   England    False   Home
# 4            Friendly  Glasgow  Scotland    False   Home
# ...               ...      ...       ...      ...    ...
# 44342  FIFA World Cup   Lusail     Qatar     True   Away
# 44343  FIFA World Cup     Doha     Qatar     True   Away
# 44344  FIFA World Cup  Al Khor     Qatar     True   Away
# 44345  FIFA World Cup   Lusail     Qatar     True   Away
# 44346  FIFA World Cup  Al Khor     Qatar     True   Away
#
# [88694 rows x 10 columns]

# %%
#shape of newly formatted data
results.shape
# Out:
# (88694, 10)

# %%
#shape of original data
df.shape
# Out:
# (44347, 9)

# %%
#number of matches
results['p'] = 1

#wins
def set_result(row):
    if row["team_score"] > row["opponent_score"]:
        return 1
    else:
        return 0
results = results.assign(w = results.apply(set_result, axis=1))

#draws
def set_result(row):
    if row["team_score"] == row["opponent_score"]:
        return 1
    else:
        return 0
results = results.assign(d = results.apply(set_result, axis=1))

#losses
def set_result(row):
    if row["team_score"] < row["opponent_score"]:
        return 1
    else:
        return 0
results = results.assign(l = results.apply(set_result, axis=1))

results
# Out:
#             date       team     opponent  team_score  opponent_score  \
# 0     1872-11-30   Scotland      England           0               0
# 1     1873-03-08    England     Scotland           4               2
# 2     1874-03-07   Scotland      England           2               1
# 3     1875-03-06    England     Scotland           2               2
# 4     1876-03-04   Scotland      England           3               0
# ...          ...        ...          ...         ...             ...
# 44342 2022-12-09  Argentina  Netherlands           2               2
# 44343 2022-12-10   Portugal      Morocco           0               1
# 44344 2022-12-10     France      England           2               1
# 44345 2022-12-13    Croatia    Argentina           0               3
# 44346 2022-12-14    Morocco       France           0               2
#
#            tournament     city   country  neutral h_or_a  p  w  d  l
# 0            Friendly  Glasgow  Scotland    False   Home  1  0  1  0
# 1            Friendly   London   England    False   Home  1  1  0  0
# 2            Friendly  Glasgow  Scotland    False   Home  1  1  0  0
# 3            Friendly   London   England    False   Home  1  0  1  0
# 4            Friendly  Glasgow  Scotland    False   Home  1  1  0  0
# ...               ...      ...       ...      ...    ... .. .. .. ..
# 44342  FIFA World Cup   Lusail     Qatar     True   Away  1  0  1  0
# 44343  FIFA World Cup     Doha     Qatar     True   Away  1  0  0  1
# 44344  FIFA World Cup  Al Khor     Qatar     True   Away  1  1  0  0
# 44345  FIFA World Cup   Lusail     Qatar     True   Away  1  0  0  1
# 44346  FIFA World Cup  Al Khor     Qatar     True   Away  1  0  0  1
#
# [88694 rows x 14 columns]

# %%
#2022 World Cup matches
wc_matches_2022 = results[(results['tournament'] == 'FIFA World Cup') &
                          (results['date'] >= '2022-11-20') & 
                          (results['date'] <= '2022-12-18')]
wc_matches_2022.head()
# Out:
#             date           team      opponent  team_score  opponent_score  \
# 44285 2022-11-20          Qatar       Ecuador           0               2
# 44286 2022-11-21        Senegal   Netherlands           0               2
# 44287 2022-11-21        England          Iran           6               2
# 44288 2022-11-21  United States         Wales           1               1
# 44289 2022-11-22      Argentina  Saudi Arabia           1               2
#
#            tournament       city country  neutral h_or_a  p  w  d  l
# 44285  FIFA World Cup    Al Khor   Qatar    False   Home  1  0  0  1
# 44286  FIFA World Cup       Doha   Qatar     True   Home  1  0  0  1
# 44287  FIFA World Cup  Al Rayyan   Qatar     True   Home  1  1  0  0
# 44288  FIFA World Cup  Al Rayyan   Qatar     True   Home  1  0  1  0
# 44289  FIFA World Cup     Lusail   Qatar     True   Home  1  0  0  1

# %%
wc_matches_2022.tail()
# Out:
#             date       team     opponent  team_score  opponent_score  \
# 44342 2022-12-09  Argentina  Netherlands           2               2
# 44343 2022-12-10   Portugal      Morocco           0               1
# 44344 2022-12-10     France      England           2               1
# 44345 2022-12-13    Croatia    Argentina           0               3
# 44346 2022-12-14    Morocco       France           0               2
#
#            tournament     city country  neutral h_or_a  p  w  d  l
# 44342  FIFA World Cup   Lusail   Qatar     True   Away  1  0  1  0
# 44343  FIFA World Cup     Doha   Qatar     True   Away  1  0  0  1
# 44344  FIFA World Cup  Al Khor   Qatar     True   Away  1  1  0  0
# 44345  FIFA World Cup   Lusail   Qatar     True   Away  1  0  0  1
# 44346  FIFA World Cup  Al Khor   Qatar     True   Away  1  0  0  1

# %% [markdown]
# ## Poisson Distribution for all matches involving World Cup semi-finalists
#
# This time, instead of using historical match data before the World Cup, I'm going to use actual World Cup match data to make my predictions. Each semi-finalist has played six games so far. Usually, a team's most recent 6-8 matches is a good barometer of team form.

# %%
semi_teams = ['Argentina', 'Croatia', 'France', 'Morocco']
semi_matches = wc_matches_2022[(wc_matches_2022['team'].isin(semi_teams)) | 
                               (wc_matches_2022['opponent'].isin(semi_teams))]
semi_matches
# Out:
#             date          team      opponent  team_score  opponent_score  \
# 44289 2022-11-22     Argentina  Saudi Arabia           1               2
# 44292 2022-11-22        France     Australia           4               1
# 44295 2022-11-23       Morocco       Croatia           0               0
# 44306 2022-11-26     Argentina        Mexico           2               0
# 44308 2022-11-26        France       Denmark           2               1
# 44311 2022-11-27       Belgium       Morocco           0               2
# 44312 2022-11-27       Croatia        Canada           4               1
# 44321 2022-11-30        Poland     Argentina           0               2
# 44324 2022-11-30       Tunisia        France           1               0
# 44327 2022-12-01       Croatia       Belgium           0               0
# 44328 2022-12-01        Canada       Morocco           1               2
# 44334 2022-12-03     Argentina     Australia           2               1
# 44335 2022-12-04        France        Poland           3               1
# 44337 2022-12-05         Japan       Croatia           1               1
# 44339 2022-12-06       Morocco         Spain           0               0
# 44341 2022-12-09       Croatia        Brazil           1               1
# 44342 2022-12-09   Netherlands     Argentina           2               2
# 44343 2022-12-10       Morocco      Portugal           1               0
# 44344 2022-12-10       England        France           1               2
# 44345 2022-12-13     Argentina       Croatia           3               0
# 44346 2022-12-14        France       Morocco           2               0
# 44289 2022-11-22  Saudi Arabia     Argentina           2               1
# 44292 2022-11-22     Australia        France           1               4
# 44295 2022-11-23       Croatia       Morocco           0               0
# 44306 2022-11-26        Mexico     Argentina           0               2
# 44308 2022-11-26       Denmark        France           1               2
# 44311 2022-11-27       Morocco       Belgium           2               0
# 44312 2022-11-27        Canada       Croatia           1               4
# 44321 2022-11-30     Argentina        Poland           2               0
# 44324 2022-11-30        France       Tunisia           0               1
# 44327 2022-12-01       Belgium       Croatia           0               0
# 44328 2022-12-01       Morocco        Canada           2               1
# 44334 2022-12-03     Australia     Argentina           1               2
# 44335 2022-12-04        Poland        France           1               3
# 44337 2022-12-05       Croatia         Japan           1               1
# 44339 2022-12-06         Spain       Morocco           0               0
# 44341 2022-12-09        Brazil       Croatia           1               1
# 44342 2022-12-09     Argentina   Netherlands           2               2
# 44343 2022-12-10      Portugal       Morocco           0               1
# 44344 2022-12-10        France       England           2               1
# 44345 2022-12-13       Croatia     Argentina           0               3
# 44346 2022-12-14       Morocco        France           0               2
#
#            tournament       city country  neutral h_or_a  p  w  d  l
# 44289  FIFA World Cup     Lusail   Qatar     True   Home  1  0  0  1
# 44292  FIFA World Cup  Al Wakrah   Qatar     True   Home  1  1  0  0
# 44295  FIFA World Cup    Al Khor   Qatar     True   Home  1  0  1  0
# 44306  FIFA World Cup     Lusail   Qatar     True   Home  1  1  0  0
# 44308  FIFA World Cup       Doha   Qatar     True   Home  1  1  0  0
# 44311  FIFA World Cup       Doha   Qatar     True   Home  1  0  0  1
# 44312  FIFA World Cup  Al Rayyan   Qatar     True   Home  1  1  0  0
# 44321  FIFA World Cup       Doha   Qatar     True   Home  1  0  0  1
# 44324  FIFA World Cup  Al Rayyan   Qatar     True   Home  1  1  0  0
# 44327  FIFA World Cup  Al Rayyan   Qatar     True   Home  1  0  1  0
# 44328  FIFA World Cup       Doha   Qatar     True   Home  1  0  0  1
# 44334  FIFA World Cup  Al Rayyan   Qatar     True   Home  1  1  0  0
# 44335  FIFA World Cup       Doha   Qatar     True   Home  1  1  0  0
# 44337  FIFA World Cup  Al Wakrah   Qatar     True   Home  1  0  1  0
# 44339  FIFA World Cup  Al Rayyan   Qatar     True   Home  1  0  1  0
# 44341  FIFA World Cup  Al Rayyan   Qatar     True   Home  1  0  1  0
# 44342  FIFA World Cup     Lusail   Qatar     True   Home  1  0  1  0
# 44343  FIFA World Cup       Doha   Qatar     True   Home  1  1  0  0
# 44344  FIFA World Cup    Al Khor   Qatar     True   Home  1  0  0  1
# 44345  FIFA World Cup     Lusail   Qatar     True   Home  1  1  0  0
# 44346  FIFA World Cup    Al Khor   Qatar     True   Home  1  1  0  0
# 44289  FIFA World Cup     Lusail   Qatar     True   Away  1  1  0  0
# 44292  FIFA World Cup  Al Wakrah   Qatar     True   Away  1  0  0  1
# 44295  FIFA World Cup    Al Khor   Qatar     True   Away  1  0  1  0
# 44306  FIFA World Cup     Lusail   Qatar     True   Away  1  0  0  1
# 44308  FIFA World Cup       Doha   Qatar     True   Away  1  0  0  1
# 44311  FIFA World Cup       Doha   Qatar     True   Away  1  1  0  0
# 44312  FIFA World Cup  Al Rayyan   Qatar     True   Away  1  0  0  1
# 44321  FIFA World Cup       Doha   Qatar     True   Away  1  1  0  0
# 44324  FIFA World Cup  Al Rayyan   Qatar     True   Away  1  0  0  1
# 44327  FIFA World Cup  Al Rayyan   Qatar     True   Away  1  0  1  0
# 44328  FIFA World Cup       Doha   Qatar     True   Away  1  1  0  0
# 44334  FIFA World Cup  Al Rayyan   Qatar     True   Away  1  0  0  1
# 44335  FIFA World Cup       Doha   Qatar     True   Away  1  0  0  1
# 44337  FIFA World Cup  Al Wakrah   Qatar     True   Away  1  0  1  0
# 44339  FIFA World Cup  Al Rayyan   Qatar     True   Away  1  0  1  0
# 44341  FIFA World Cup  Al Rayyan   Qatar     True   Away  1  0  1  0
# 44342  FIFA World Cup     Lusail   Qatar     True   Away  1  0  1  0
# 44343  FIFA World Cup       Doha   Qatar     True   Away  1  0  0  1
# 44344  FIFA World Cup    Al Khor   Qatar     True   Away  1  1  0  0
# 44345  FIFA World Cup     Lusail   Qatar     True   Away  1  0  0  1
# 44346  FIFA World Cup    Al Khor   Qatar     True   Away  1  0  0  1

# %%
#create standings table for each team
table = semi_matches[['team','p','w','d','l','team_score','opponent_score']]
table = table.rename(columns = {'team_score':'gf',
                                            'opponent_score':'ga'})
table = table.groupby(by = 'team').sum().sort_values('team', ascending = True)

table['gd'] = table['gf'] - table['ga']
table['gpg_scored'] = table['gf'] / table['p']
table['gpg_conceded'] = table['ga'] / table['p']

table = table.reset_index()
table
# Out:
#             team  p  w  d  l  gf  ga  gd  gpg_scored  gpg_conceded
# 0      Argentina  6  4  1  1  12   5   7    2.000000      0.833333
# 1      Australia  2  0  0  2   2   6  -4    1.000000      3.000000
# 2        Belgium  2  0  1  1   0   2  -2    0.000000      1.000000
# 3         Brazil  1  0  1  0   1   1   0    1.000000      1.000000
# 4         Canada  2  0  0  2   2   6  -4    1.000000      3.000000
# 5        Croatia  6  1  4  1   6   6   0    1.000000      1.000000
# 6        Denmark  1  0  0  1   1   2  -1    1.000000      2.000000
# 7        England  1  0  0  1   1   2  -1    1.000000      2.000000
# 8         France  6  5  0  1  13   5   8    2.166667      0.833333
# 9          Japan  1  0  1  0   1   1   0    1.000000      1.000000
# 10        Mexico  1  0  0  1   0   2  -2    0.000000      2.000000
# 11       Morocco  6  3  2  1   5   3   2    0.833333      0.500000
# 12   Netherlands  1  0  1  0   2   2   0    2.000000      2.000000
# 13        Poland  2  0  0  2   1   5  -4    0.500000      2.500000
# 14      Portugal  1  0  0  1   0   1  -1    0.000000      1.000000
# 15  Saudi Arabia  1  1  0  0   2   1   1    2.000000      1.000000
# 16         Spain  1  0  1  0   0   0   0    0.000000      0.000000
# 17       Tunisia  1  1  0  0   1   0   1    1.000000      0.000000

# %%
#tiebreaker
table_gd = table[['team', 'gd']]
table_gd
# Out:
#             team  gd
# 0      Argentina   7
# 1      Australia  -4
# 2        Belgium  -2
# 3         Brazil   0
# 4         Canada  -4
# 5        Croatia   0
# 6        Denmark  -1
# 7        England  -1
# 8         France   8
# 9          Japan   0
# 10        Mexico  -2
# 11       Morocco   2
# 12   Netherlands   0
# 13        Poland  -4
# 14      Portugal  -1
# 15  Saudi Arabia   1
# 16         Spain   0
# 17       Tunisia   1

# %%
#goals scored per game for all teams
avg_goals = table['gf'].sum() / table['p'].sum()
avg_goals
# Out:
# 1.1904761904761905

# %%
#goals conceded per game for all teams (should be the same as avg_goals)
table['ga'].sum() / table['p'].sum()
# Out:
# 1.1904761904761905

# %%
#calculate strengths
strengths = semi_matches.groupby(['team']).mean().sort_values('team', ascending = True)
strengths = strengths.reset_index()
strengths = strengths[['team', 'team_score', 'opponent_score']]
strengths['att'] = strengths['team_score'] / avg_goals
strengths['def'] = strengths['opponent_score'] / avg_goals
strengths = strengths[['team', 'att', 'def']]
strengths_team = strengths.rename(columns = {'att':'team_att',
                                             'def':'team_def'})
strengths_opponent = strengths.rename(columns = {'team':'opponent',
                                                 'att':'opponent_att',
                                                 'def':'opponent_def'})
strengths = strengths[(strengths['team'].isin(semi_teams))]
strengths
# Out:
#          team   att   def
# 0   Argentina  1.68  0.70
# 5     Croatia  0.84  0.84
# 8      France  1.82  0.70
# 11    Morocco  0.70  0.42

# %%
#third place game
third_place = {'Home':['Croatia'],
               'Away':['Morocco']}
third_place = pd.DataFrame(third_place)

third_place = pd.merge(third_place, strengths, left_on = 'Home', right_on = 'team')
third_place = pd.merge(third_place, strengths, left_on = 'Away', right_on = 'team')
third_place = third_place.drop(['team_x','team_y'], axis = 1)
third_place = third_place.rename(columns = {'att_x':'Home_Att', 'def_x':'Home_Def',
                                            'att_y':'Away_Att', 'def_y':'Away_Def'})

third_place['Home_xG'] = third_place['Home_Att'] * third_place['Away_Def'] * avg_goals
third_place['Away_xG'] = third_place['Away_Att'] * third_place['Home_Def'] * avg_goals
third_place['Home_Score'] = third_place['Home_xG'].round()
third_place['Away_Score'] = third_place['Away_xG'].round()

third_place['Winner'] = np.where(third_place['Home_xG'] > third_place['Away_xG'], third_place['Home'],
                        np.where(third_place['Home_xG'] < third_place['Away_xG'], third_place['Away'], 'Draw'))

third_place
# Out:
#       Home     Away  Home_Att  Home_Def  Away_Att  Away_Def  Home_xG  Away_xG  \
# 0  Croatia  Morocco      0.84      0.84       0.7      0.42     0.42      0.7
#
#    Home_Score  Away_Score   Winner
# 0         0.0         1.0  Morocco

# %%
#final
final = {'Home':['Argentina'],
         'Away':['France']}
final = pd.DataFrame(final)

final = pd.merge(final, strengths, left_on = 'Home', right_on = 'team')
final = pd.merge(final, strengths, left_on = 'Away', right_on = 'team')
final = final.drop(['team_x','team_y'], axis = 1)
final = final.rename(columns = {'att_x':'Home_Att', 'def_x':'Home_Def',
                                'att_y':'Away_Att', 'def_y':'Away_Def'})

final['Home_xG'] = final['Home_Att'] * final['Away_Def'] * avg_goals
final['Away_xG'] = final['Away_Att'] * final['Home_Def'] * avg_goals
final['Home_Score'] = final['Home_xG'].round()
final['Away_Score'] = final['Away_xG'].round()

final['Winner'] = np.where(final['Home_xG'] > final['Away_xG'], final['Home'],
                  np.where(final['Home_xG'] < final['Away_xG'], final['Away'], 'Draw'))

final
# Out:
#         Home    Away  Home_Att  Home_Def  Away_Att  Away_Def  Home_xG  \
# 0  Argentina  France      1.68       0.7      1.82       0.7      1.4
#
#     Away_xG  Home_Score  Away_Score  Winner
# 0  1.516667         1.0         2.0  France
